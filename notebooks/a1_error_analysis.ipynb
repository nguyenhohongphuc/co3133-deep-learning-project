# %% [markdown]
# # A1-17 - Error analysis & inductive bias (TV 3)
# Handbook 3.3: for each error group give description, rate, examples, hypothesised cause and an improvement idea. Then compare flattened vs spatial vs sequence representations (12.1) - accuracy alone is not a conclusion.
